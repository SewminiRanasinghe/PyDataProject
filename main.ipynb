# %%
import pandas as pd
import glob


csv_files = glob.glob("WorldCup_Stats/*.csv") 
dataframes = [pd.read_csv(file) for file in csv_files]


crick_df = pd.concat(dataframes, ignore_index=True)


crick_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        date        venue match_category team_1  \
# 0             0           6         NaN   Manchester   League-Match    CAN
# 1             1           2         NaN       Lord's   League-Match    AUS
# 2             2           8  1979-06-16   Manchester   League-Match     SL
# 3             3           5         NaN   Nottingham   League-Match    PAK
# 4             4          10         NaN   Birmingham   League-Match    CAN
#
#   team_2  team_1_runs  team_1_wickets  team_2_runs  team_2_wickets  \
# 0    ENG         45.0             0.0         46.0             2.0
# 1    ENG        159.0             9.0        160.0             4.0
# 2    IND        238.0             5.0        191.0             0.0
# 3    AUS        286.0             7.0        197.0             0.0
# 4    AUS        105.0             0.0        106.0             3.0
#
#                                               result            pom  \
# 0  England won by 8 wickets (with 277 balls remai...      Chris Old
# 1  England won by 6 wickets (with 77 balls remain...   Graham Gooch
# 2                           Sri Lanka won by 47 runs  Duleep Mendis
# 3                            Pakistan won by 89 runs     Asif Iqbal
# 4  Australia won by 7 wickets (with 204 balls rem...     Alan Hurst
#
#   best_batters best_bowlers commentary_line  world_cup_year host_country
# 0          NaN          NaN             NaN            1979      England
# 1          NaN          NaN             NaN            1979      England
# 2          NaN          NaN             NaN            1979      England
# 3          NaN          NaN             NaN            1979      England
# 4          NaN          NaN             NaN            1979      England

# %%
# Remove duplicate records & Remove rows with null values
crick_df.drop_duplicates(inplace=True)
crick_df.dropna(inplace=True)

crick_df.head(10)
# Out:
#     Unnamed: 0.1  Unnamed: 0        date               venue match_category  \
# 61             4          30  2019-06-24         Southampton   League-Match
# 62             5          27  2019-06-22         Southampton   League-Match
# 64             7          40  2019-07-03   Chester-le-Street   League-Match
# 67            10          47  2019-07-14              Lord's          Final
# 69            12          18  2019-06-14         Southampton   League-Match
# 70            13          45  2019-07-09          Manchester   League-Match
# 71            14           7  2019-06-05         Southampton   League-Match
# 72            15          19  2019-06-15            The Oval   League-Match
# 75            18          46  2019-07-11          Birmingham   League-Match
# 76            19           0  2019-05-30            The Oval   League-Match
#
#    team_1 team_2  team_1_runs  team_1_wickets  team_2_runs  team_2_wickets  \
# 61    BAN    AFG        262.0             7.0        200.0             0.0
# 62    IND    AFG        224.0             8.0        213.0             0.0
# 64    ENG     NZ        305.0             8.0        186.0             0.0
# 67     NZ    ENG        241.0             8.0        241.0             0.0
# 69     WI    ENG        212.0             0.0        213.0             2.0
# 70     NZ    IND        239.0             8.0        221.0             0.0
# 71     SA    IND        227.0             9.0        230.0             4.0
# 72    AUS     SL        334.0             7.0        247.0             0.0
# 75    AUS    ENG        223.0             0.0        226.0             2.0
# 76    ENG     SA        311.0             8.0        207.0             0.0
#
#                                                result              pom  \
# 61                          Bangladesh won by 62 runs  Shakib Al Hasan
# 62                               India won by 11 runs   Jasprit Bumrah
# 64                            England won by 119 runs   Jonny Bairstow
# 67         Match tied (England won on boundary count)       Ben Stokes
# 69  England won by 8 wickets (with 101 balls remai...         Joe Root
# 70                         New Zealand won by 18 runs       Matt Henry
# 71   India won by 6 wickets (with 15 balls remaining)     Rohit Sharma
# 72                           Australia won by 87 runs      Aaron Finch
# 75  England won by 8 wickets (with 107 balls remai...     Chris Woakes
# 76                            England won by 104 runs       Ben Stokes
#
#                                          best_batters  \
# 61  ['Mushfiqur Rahim - 83 runs ', 'Shakib Al Hasa...
# 62  ['V Kohli - 67 runs ', 'Mohammad Nabi - 52 run...
# 64   ['JM Bairstow - 106 runs ', 'JJ Roy - 60 runs ']
# 67  ['BA Stokes - 84 runs ', 'JC Buttler - 59 runs ']
# 69     ['JE Root - 100 runs ', 'N Pooran - 63 runs ']
# 70  ['RA Jadeja - 77 runs ', 'LRPL Taylor - 74 run...
# 71  ['RG Sharma - 122 runs ', 'CH Morris - 42 runs ']
# 72  ['AJ Finch - 153 runs ', 'FDM Karunaratne - 97...
# 75      ['JJ Roy - 85 runs ', 'SPD Smith - 85 runs ']
# 76   ['BA Stokes - 89 runs ', 'Q de Kock - 68 runs ']
#
#                                        best_bowlers  \
# 61  ['Shakib Al Hasan - 5', 'Mujeeb Ur Rahman - 3']
# 62          ['Mohammed Shami - 4', 'YS Chahal - 2']
# 64               ['MA Wood - 3', 'JDS Neesham - 2']
# 67             ['CR Woakes - 3', 'LE Plunkett - 3']
# 69                 ['MA Wood - 3', 'JC Archer - 3']
# 70                  ['MJ Henry - 3', 'B Kumar - 3']
# 71               ['YS Chahal - 4', 'JJ Bumrah - 2']
# 72            ['MA Starc - 4', 'KW Richardson - 3']
# 75               ['CR Woakes - 3', 'AU Rashid - 3']
# 76                 ['JC Archer - 3', 'L Ngidi - 3']
#
#                                       commentary_line  world_cup_year  \
# 61  I think we missed something this tournament, w...            2019
# 62  Gulbadin Naib: "We bowled really well, and eve...            2019
# 64  Meanwhile, kudos to Sachin Tendulkar ... who t...            2019
# 67  And what of New Zealand? They've been through ...            2019
# 69  Jason Holder tells Nasser: "I don't think we p...            2019
# 70  Ragha: "It feels impossible to control my tear...            2019
# 71  [On decision to bat]: Had we had Steyn and Ngi...            2019
# 72  Dimuth Karunaratne: "Finch and Smith batted we...            2019
# 75  5.15pm: We are going to see a new name on cup....            2019
# 76  5.56pm Jofra Archer is having a chat with Sky,...            2019
#
#    host_country
# 61      England
# 62      England
# 64      England
# 67      England
# 69      England
# 70      England
# 71      England
# 72      England
# 75      England
# 76      England

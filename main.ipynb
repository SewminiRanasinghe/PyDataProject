# %%
import pandas as pd
import glob


csv_files = glob.glob("WorldCup_Stats/*.csv") 
dataframes = [pd.read_csv(file) for file in csv_files]


crick_df = pd.concat(dataframes, ignore_index=True)


crick_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        date        venue match_category team_1  \
# 0             0           6         NaN   Manchester   League-Match    CAN
# 1             1           2         NaN       Lord's   League-Match    AUS
# 2             2           8  1979-06-16   Manchester   League-Match     SL
# 3             3           5         NaN   Nottingham   League-Match    PAK
# 4             4          10         NaN   Birmingham   League-Match    CAN
#
#   team_2  team_1_runs  team_1_wickets  team_2_runs  team_2_wickets  \
# 0    ENG         45.0             0.0         46.0             2.0
# 1    ENG        159.0             9.0        160.0             4.0
# 2    IND        238.0             5.0        191.0             0.0
# 3    AUS        286.0             7.0        197.0             0.0
# 4    AUS        105.0             0.0        106.0             3.0
#
#                                               result            pom  \
# 0  England won by 8 wickets (with 277 balls remai...      Chris Old
# 1  England won by 6 wickets (with 77 balls remain...   Graham Gooch
# 2                           Sri Lanka won by 47 runs  Duleep Mendis
# 3                            Pakistan won by 89 runs     Asif Iqbal
# 4  Australia won by 7 wickets (with 204 balls rem...     Alan Hurst
#
#   best_batters best_bowlers commentary_line  world_cup_year host_country
# 0          NaN          NaN             NaN            1979      England
# 1          NaN          NaN             NaN            1979      England
# 2          NaN          NaN             NaN            1979      England
# 3          NaN          NaN             NaN            1979      England
# 4          NaN          NaN             NaN            1979      England

# %% [markdown]
# Assume null recodes as which contains all columns are null

# %%
#Data exploration
print(crick_df.info())
print(crick_df.describe())

# Remove duplicate records & Remove rows with null values
crick_df.drop_duplicates(inplace=True)
crick_df.dropna(how='all' ,inplace=True)

crick_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0.1     528 non-null    int64
#  1   Unnamed: 0       528 non-null    int64
#  2   date             364 non-null    object
#  3   venue            528 non-null    object
#  4   match_category   528 non-null    object
#  5   team_1           528 non-null    object
#  6   team_2           528 non-null    object
#  7   team_1_runs      518 non-null    float64
#  8   team_1_wickets   518 non-null    float64
#  9   team_2_runs      513 non-null    float64
#  10  team_2_wickets   513 non-null    float64
#  11  result           528 non-null    object
#  12  pom              510 non-null    object
#  13  best_batters     250 non-null    object
#  14  best_bowlers     250 non-null    object
#  15  commentary_line  83 non-null     object
#  16  world_cup_year   528 non-null    int64
#  17  host_country     528 non-null    object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 74.4+ KB
# None
#        Unnamed: 0.1  Unnamed: 0  team_1_runs  team_1_wickets  team_2_runs  \
# count    528.000000  528.000000   518.000000      518.000000   513.000000
# mean      21.871212   21.034091   243.239382        4.590734   198.643275
# std       14.307231   13.915398    75.108565        3.465005    59.732864
# min        0.000000    0.000000     1.000000        0.000000    24.000000
# 25%       10.000000    9.000000   197.000000        0.000000   158.000000
# 50%       20.000000   20.000000   244.000000        6.000000   204.000000
# 75%       33.000000   32.000000   292.000000        8.000000   235.000000
# max       55.000000   53.000000   428.000000        9.000000   383.000000
#
#        team_2_wickets  world_cup_year
# count      513.000000      528.000000
# mean         2.777778     2003.373106
# std          3.044163       13.352007
# min          0.000000     1975.000000
# 25%          0.000000     1992.000000
# 50%          2.000000     2003.000000
# 75%          5.000000     2015.000000
# max          9.000000     2023.000000
#    Unnamed: 0.1  Unnamed: 0        date        venue match_category team_1  \
# 0             0           6         NaN   Manchester   League-Match    CAN
# 1             1           2         NaN       Lord's   League-Match    AUS
# 2             2           8  1979-06-16   Manchester   League-Match     SL
# 3             3           5         NaN   Nottingham   League-Match    PAK
# 4             4          10         NaN   Birmingham   League-Match    CAN
# 5             5          11         NaN        Leeds   League-Match    ENG
# 6             6          13         NaN     The Oval     Semi-Final     WI
# 7             7           6         NaN   Manchester   League-Match    CAN
# 8             8          12  1979-06-20   Manchester     Semi-Final    ENG
# 9             9           1         NaN   Nottingham   League-Match     SL
#
#   team_2  team_1_runs  team_1_wickets  team_2_runs  team_2_wickets  \
# 0    ENG         45.0             0.0         46.0             2.0
# 1    ENG        159.0             9.0        160.0             4.0
# 2    IND        238.0             5.0        191.0             0.0
# 3    AUS        286.0             7.0        197.0             0.0
# 4    AUS        105.0             0.0        106.0             3.0
# 5    PAK        165.0             9.0        151.0             0.0
# 6    PAK        293.0             6.0        250.0             0.0
# 7    ENG         45.0             0.0         46.0             2.0
# 8     NZ        221.0             8.0        212.0             9.0
# 9     NZ        189.0             0.0        190.0             1.0
#
#                                               result               pom  \
# 0  England won by 8 wickets (with 277 balls remai...         Chris Old
# 1  England won by 6 wickets (with 77 balls remain...      Graham Gooch
# 2                           Sri Lanka won by 47 runs     Duleep Mendis
# 3                            Pakistan won by 89 runs        Asif Iqbal
# 4  Australia won by 7 wickets (with 204 balls rem...        Alan Hurst
# 5                             England won by 14 runs     Mike Hendrick
# 6                         West Indies won by 43 runs  Gordon Greenidge
# 7  England won by 8 wickets (with 277 balls remai...         Chris Old
# 8                              England won by 9 runs      Graham Gooch
# 9  New Zealand won by 9 wickets (with 74 balls re...     Geoff Howarth
#
#   best_batters best_bowlers commentary_line  world_cup_year host_country
# 0          NaN          NaN             NaN            1979      England
# 1          NaN          NaN             NaN            1979      England
# 2          NaN          NaN             NaN            1979      England
# 3          NaN          NaN             NaN            1979      England
# 4          NaN          NaN             NaN            1979      England
# 5          NaN          NaN             NaN            1979      England
# 6          NaN          NaN             NaN            1979      England
# 7          NaN          NaN             NaN            1979      England
# 8          NaN          NaN             NaN            1979      England
# 9          NaN          NaN             NaN            1979      England

# %% [markdown]
# This is to clean the data by removing matches with abnormally high or low runs scored by either team, as these might be errors or extreme anomalies that could skew the analysis.

# %%
#Removing outliers for numerical columns
from scipy.stats import zscore

num_cols = ['team_1_runs', 'team_2_runs']
crick_df = crick_df[(zscore(crick_df[num_cols]) < 3).all(axis=1)]

crick_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, date, venue, match_category, team_1, team_2, team_1_runs, team_1_wickets, team_2_runs, team_2_wickets, result, pom, best_batters, best_bowlers, commentary_line, world_cup_year, host_country]
# Index: []

# %%
#Adding new columns to the DataFrame: match_status 
crick_df['match_status'] = crick_df['result'].apply(
    lambda x: 'abandoned' if 'abandoned' in x.lower() else 'played'
)

crick_df.head(10)
# Out:
#      Unnamed: 0.1  Unnamed: 0        date           venue match_category  \
# 326             0           3  2011-02-21       Ahmedabad   League-Match
# 327             1          48  2011-04-02        Wankhede          Final
# 328             2          28  2011-03-12          Nagpur   League-Match
# 329             3          40  2011-03-20    Eden Gardens   League-Match
# 332             6          42  2011-03-23          Mirpur          Final
# 338            12          45  2011-03-26   Colombo (RPS)          Final
# 341            15          43  2011-03-24       Ahmedabad          Final
# 342            16           7  2011-02-25          Nagpur   League-Match
# 343            17          38  2011-03-19          Mirpur   League-Match
# 347            21          46  2011-03-29   Colombo (RPS)     Semi-Final
#
#     team_1 team_2  team_1_runs  team_1_wickets  team_2_runs  team_2_wickets  \
# 326    AUS    ZIM        262.0             6.0        171.0             0.0
# 327     SL    IND        274.0             6.0        277.0             4.0
# 328    IND     SA        296.0             0.0        300.0             7.0
# 329    ZIM  KENYA        308.0             6.0        147.0             0.0
# 332     WI    PAK        112.0             0.0        113.0             0.0
# 338    ENG     SL        229.0             6.0        231.0             0.0
# 341    AUS    IND        260.0             6.0        261.0             5.0
# 342     NZ    AUS        206.0             0.0        207.0             3.0
# 343     SA    BAN        284.0             8.0         78.0             0.0
# 347     NZ     SL        217.0             0.0        220.0             5.0
#
#                                                 result                   pom  \
# 326                           Australia won by 91 runs          Shane Watson
# 327   India won by 6 wickets (with 10 balls remaining)              MS Dhoni
# 328  South Africa won by 3 wickets (with 2 balls re...            Dale Steyn
# 329                           Zimbabwe won by 161 runs          Craig Ervine
# 332  Pakistan won by 10 wickets (with 175 balls rem...       Mohammad Hafeez
# 338  Sri Lanka won by 10 wickets (with 63 balls rem...  Tillakaratne Dilshan
# 341   India won by 5 wickets (with 14 balls remaining)          Yuvraj Singh
# 342  Australia won by 7 wickets (with 96 balls rema...      Mitchell Johnson
# 343                       South Africa won by 206 runs      Lonwabo Tsotsobe
# 347  Sri Lanka won by 5 wickets (with 13 balls rema...      Kumar Sangakkara
#
#                                           best_batters  \
# 326   ['SR Watson - 79 runs ', 'MJ Clarke - 58 runs ']
# 327  ['DPMD Jayawardene - 103 runs ', 'G Gambhir - ...
# 328  ['SR Tendulkar - 111 runs ', 'V Sehwag - 73 ru...
# 329   ['CR Ervine - 66 runs ', 'V Sibanda - 61 runs ']
# 332  ['Mohammad Hafeez - 61 runs ', 'Kamran Akmal -...
# 338  ['TM Dilshan - 108 runs ', 'WU Tharanga - 102 ...
# 341  ['RT Ponting - 104 runs ', 'Yuvraj Singh - 57 ...
# 342   ['SR Watson - 62 runs ', 'BJ Haddin - 55 runs ']
# 343  ['JH Kallis - 69 runs ', 'F du Plessis - 52 ru...
# 347  ['TM Dilshan - 73 runs ', 'SB Styris - 57 runs ']
#
#                                      best_bowlers  \
# 326           ['MG Johnson - 4', 'JJ Krejza - 2']
# 327        ['SL Malinga - 2', 'Yuvraj Singh - 2']
# 328       ['DW Steyn - 5', 'Harbhajan Singh - 3']
# 329               ['RW Price - 2', 'GA Lamb - 2']
# 332  ['Shahid Afridi - 4', 'Mohammad Hafeez - 2']
# 338       ['M Muralidaran - 2', 'BAW Mendis - 1']
# 341          ['Yuvraj Singh - 2', 'R Ashwin - 2']
# 342             ['MG Johnson - 4', 'SW Tait - 3']
# 343        ['RJ Peterson - 4', 'LL Tsotsobe - 3']
# 347          ['BAW Mendis - 3', 'TG Southee - 3']
#
#                                        commentary_line  world_cup_year  \
# 326       The presentation ceremony is about to begin.            2011
# 327  Now Yusuf Pathan and Raina carry Tendulkar. Th...            2011
# 328  Robin Peterson: "I'm extremely ecstatic at the...            2011
# 329  Steve Tikolo: "We are disappointed. We wanted ...            2011
# 332  'Clinical Pakistan storm into semi-final' is t...            2011
# 338  Kumar Sangakkara "Losing the toss it was an im...            2011
# 341  After hurtling through the group stages unconv...            2011
# 342  Ponting: "Good game for us today. NZ are a ver...            2011
# 343  Please do wait for the quotes from the post-ma...            2011
# 347  As for the big match tomorrow, there's some ba...            2011
#
#     host_country match_status
# 326        India       played
# 327        India       played
# 328        India       played
# 329        India       played
# 332   Bangladesh       played
# 338    Sri Lanka       played
# 341        India       played
# 342        India       played
# 343   Bangladesh       played
# 347    Sri Lanka       played
